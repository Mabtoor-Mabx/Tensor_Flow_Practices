# %% [markdown]
# **Using TensorFLow with Numpy**

# %%
import tensorflow as tf
import numpy as np

# %%
numpy_A = tf.constant(np.array([1,3,4]))
numpy_A
# Out:
# <tf.Tensor: shape=(3,), dtype=int64, numpy=array([1, 3, 4])>

# %%
numpy_B = np.array(numpy_A)

# %%
numpy_B
# Out:
# array([1, 3, 4])

# %%
numpy_A = tf.constant(np.array([1.,3.,6.]))
tensor_A = tf.constant([1.,3.,6.])

# %%
numpy_A.dtype
# Out:
# tf.float64

# %%
tensor_A.dtype
# Out:
# tf.float32
