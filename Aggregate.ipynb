# %%
import tensorflow as tf
import numpy as np
import math as mt

# %% [markdown]
# # Aggregate

# %%
agg = tf.constant([-1,-4,-5,-6])
agg
# Out:
# <tf.Tensor: shape=(4,), dtype=int32, numpy=array([-1, -4, -5, -6], dtype=int32)>

# %%
tf.abs(agg)
# Out:
# <tf.Tensor: shape=(4,), dtype=int32, numpy=array([1, 4, 5, 6], dtype=int32)>

# %%
E = tf.constant(np.random.randint(0,100,size=50))

# %%
E
# Out:
# <tf.Tensor: shape=(50,), dtype=int64, numpy=
# array([82, 89, 81, 95, 15, 97, 58, 13, 41, 87, 76, 50, 76, 19,  5,  6, 22,
#        76, 82, 22, 10, 61,  6, 97,  3, 52, 20, 83, 93, 42, 92, 52, 16, 44,
#        42, 26,  6, 73, 18, 50, 95,  2, 94, 31,  6, 82, 22, 86, 33, 98])>

# %%
tf.reduce_min(E)
# Out:
# <tf.Tensor: shape=(), dtype=int64, numpy=2>

# %%
tf.reduce_max(E)
# Out:
# <tf.Tensor: shape=(), dtype=int64, numpy=98>

# %%
tf.reduce_mean(E)
# Out:
# <tf.Tensor: shape=(), dtype=int64, numpy=50>

# %%
tf.reduce_sum(E)
# Out:
# <tf.Tensor: shape=(), dtype=int64, numpy=2527>

# %%
variance = tf.reduce_max(E)-tf.reduce_min(E)
variance = variance/2527-1

# %%
variance
# Out:
# <tf.Tensor: shape=(), dtype=float64, numpy=-0.962010288880095>

# %%
variance = tf.math.sqrt(variance)

# %%
variance
# Out:
# <tf.Tensor: shape=(), dtype=float64, numpy=nan>

# %%
variance
# Out:
# <tf.Tensor: shape=(), dtype=float64, numpy=nan>

# %%
tf.reduce_min(E)
# Out:
# <tf.Tensor: shape=(), dtype=int64, numpy=2>

# %%
F= tf.constant(np.random.randint(0,50,size=25))
F
# Out:
# <tf.Tensor: shape=(25,), dtype=int64, numpy=
# array([ 5, 33, 29, 43, 18, 21,  7,  0, 48, 28, 13, 33, 20, 24, 28,  0, 45,
#         7, 15, 26, 13, 31,  4,  2, 31])>

# %%
tf.reduce_min(F)
# Out:
# <tf.Tensor: shape=(), dtype=int64, numpy=0>

# %%
tf.reduce_max(F)
# Out:
# <tf.Tensor: shape=(), dtype=int64, numpy=48>

# %%
tf.reduce_mean(F)
# Out:
# <tf.Tensor: shape=(), dtype=int64, numpy=20>

# %%
tf.reduce_sum(F)
# Out:
# <tf.Tensor: shape=(), dtype=int64, numpy=524>
