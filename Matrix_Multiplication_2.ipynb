# %%
import tensorflow as tf
import numpy as np

# %% [markdown]
# #MATRIX MULTIPLICATION

# %%
matrix1= tf.constant([
                      [1,3],[4,5],[5,5]
])

# %%
matrix2= tf.constant([
                      [5,6],[0,8],[4,7]
])

# %%
matrix1+matrix2
# Out:
# <tf.Tensor: shape=(3, 2), dtype=int32, numpy=
# array([[ 6,  9],
#        [ 4, 13],
#        [ 9, 12]], dtype=int32)>

# %%
tf.matmul(tf.transpose(matrix1),matrix2)
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[25, 73],
#        [35, 93]], dtype=int32)>

# %%
tf.reshape(matrix1,shape=(2,3))
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[1, 3, 4],
#        [5, 5, 5]], dtype=int32)>

# %%
tf.matmul(matrix1,tf.transpose(matrix2))
# Out:
# <tf.Tensor: shape=(3, 3), dtype=int32, numpy=
# array([[23, 24, 25],
#        [50, 40, 51],
#        [55, 40, 55]], dtype=int32)>

# %%
matrix1.shape , matrix2.shape
# Out:
# (TensorShape([3, 2]), TensorShape([3, 2]))

# %%
tf.reshape(matrix2, shape=(2,3))
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[5, 6, 0],
#        [8, 4, 7]], dtype=int32)>

# %%
tf.matmul(matrix1, tf.reshape(matrix2, shape=(2,3)))
# Out:
# <tf.Tensor: shape=(3, 3), dtype=int32, numpy=
# array([[29, 18, 21],
#        [60, 44, 35],
#        [65, 50, 35]], dtype=int32)>

# %%
matrix3 = tf.constant([
                       [2,3],[4,5],[4,2]
])

# %%
matrix4 = tf.constant([
                       [3,4],[7,8],[2,5]
])

# %%
tf.matmul(matrix3,tf.reshape(matrix4, shape=(2,3) ))
# Out:
# <tf.Tensor: shape=(3, 3), dtype=int32, numpy=
# array([[30, 14, 29],
#        [52, 26, 53],
#        [28, 20, 38]], dtype=int32)>

# %%
matrix3.shape, matrix4.shape
# Out:
# (TensorShape([3, 2]), TensorShape([3, 2]))

# %%
matrix3 @ tf.reshape(matrix4, shape=(2,3))
# Out:
# <tf.Tensor: shape=(3, 3), dtype=int32, numpy=
# array([[30, 14, 29],
#        [52, 26, 53],
#        [28, 20, 38]], dtype=int32)>

# %%
matrix3 * matrix4
# Out:
# <tf.Tensor: shape=(3, 2), dtype=int32, numpy=
# array([[ 6, 12],
#        [28, 40],
#        [ 8, 10]], dtype=int32)>

# %%
matrix3[:2]
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[2, 3],
#        [4, 5]], dtype=int32)>

# %%
matrix1[:-1]
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[1, 3],
#        [4, 5]], dtype=int32)>

# %%
matrix1
# Out:
# <tf.Tensor: shape=(3, 2), dtype=int32, numpy=
# array([[1, 3],
#        [4, 5],
#        [5, 5]], dtype=int32)>

# %%
matrix1[...]
# Out:
# <tf.Tensor: shape=(3, 2), dtype=int32, numpy=
# array([[1, 3],
#        [4, 5],
#        [5, 5]], dtype=int32)>

# %%
matrix5 = matrix1[..., tf.newaxis]

# %%
matrix5
# Out:
# <tf.Tensor: shape=(3, 2, 1), dtype=int32, numpy=
# array([[[1],
#         [3]],
#
#        [[4],
#         [5]],
#
#        [[5],
#         [5]]], dtype=int32)>

# %%
matrix6 = tf.expand_dims(matrix5,axis=1)

# %%
matrix6
# Out:
# <tf.Tensor: shape=(3, 1, 2, 1), dtype=int32, numpy=
# array([[[[1],
#          [3]]],
#
#
#        [[[4],
#          [5]]],
#
#
#        [[[5],
#          [5]]]], dtype=int32)>

# %%
matrix6
# Out:
# <tf.Tensor: shape=(3, 1, 2, 1), dtype=int32, numpy=
# array([[[[1],
#          [3]]],
#
#
#        [[[4],
#          [5]]],
#
#
#        [[[5],
#          [5]]]], dtype=int32)>

# %%
matrix2
# Out:
# <tf.Tensor: shape=(3, 2), dtype=int32, numpy=
# array([[5, 6],
#        [0, 8],
#        [4, 7]], dtype=int32)>

# %%
tf.transpose(matrix2)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[5, 0, 4],
#        [6, 8, 7]], dtype=int32)>
