# %%
import tensorflow as tf

# %%
scalar = tf.Variable(10,4)
scalar
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=10>

# %%
change= tf.Variable([1,2])
change
# Out:
# <tf.Variable 'Variable:0' shape=(2,) dtype=int32, numpy=array([1, 2], dtype=int32)>

# %%
change[0].assign(4)
change
# Out:
# <tf.Variable 'Variable:0' shape=(2,) dtype=int32, numpy=array([4, 2], dtype=int32)>

# %%
changing = tf.Variable([
    [1,2], [3,4],[5,6],
    ])
changing
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[1, 2],
#        [3, 4],
#        [5, 6]], dtype=int32)>

# %%
change2 = tf.Variable([[1,3],[2,4]])
change2
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=int32, numpy=
# array([[1, 3],
#        [2, 4]], dtype=int32)>

# %%
# Out:
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# <ipython-input-23-b598b114209c> in <module>()
# ----> 1 change2[1].assign(2)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py in assign(val, name)
#    1243           ellipsis_mask=ellipsis_mask,
#    1244           new_axis_mask=new_axis_mask,
# -> 1245           shrink_axis_mask=shrink_axis_mask)
#    1246
#    1247     op.assign = assign
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/resource_variable_ops.py in _strided_slice_assign(self, begin, end, strides, value, name, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask)
#    1396               ellipsis_mask=ellipsis_mask,
#    1397               new_axis_mask=new_axis_mask,
# -> 1398               shrink_axis_mask=shrink_axis_mask))
#    1399
#    1400   def __complex__(self):
#
# ...
