# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.array([-7,-6,-8,-5,-9,-3,-4,-1,-2])
y = np.array([2,5,1,4,3,6,8,7,9])
X,y
# Out:
# (array([-7, -6, -8, -5, -9, -3, -4, -1, -2]),
#  array([2, 5, 1, 4, 3, 6, 8, 7, 9]))

# %%
X.size
# Out:
# 9

# %%
y.size
# Out:
# 9

# %%
plt.scatter(X,y)

# %%
X.shape
# Out:
# (9,)

# %%
y.shape
# Out:
# (9,)

# %%
X[0]
# Out:
# -7

# %%
y[0]
# Out:
# 2

# %%
X[0],y[0]
# Out:
# (-7, 2)

# %%
X[0].shape, y[0].shape
# Out:
# ((), ())

# %%
X[1].shape, y[1].shape
# Out:
# ((), ())

# %%
X.shape, y.shape
# Out:
# ((9,), (9,))

# %%
house_info = tf.constant(['Bedroom', 'bathroom', 'Garage'])
house_price = tf.constant([42176000])
house_info, house_price
# Out:
# (<tf.Tensor: shape=(3,), dtype=string, numpy=array([b'Bedroom', b'bathroom', b'Garage'], dtype=object)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([42176000], dtype=int32)>)

# %%
plt.scatter(X,y)
