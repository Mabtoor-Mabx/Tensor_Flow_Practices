# %%
import tensorflow as tf
import numpy as np

# %% [markdown]
# #Change Datatype

# %%
matrix1= tf.constant([1,4])
matrix1
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([1, 4], dtype=int32)>

# %%
matrix2 = tf.constant([1.1,4.8])
matrix2
# Out:
# <tf.Tensor: shape=(2,), dtype=float32, numpy=array([1.1, 4.8], dtype=float32)>

# %%
matrix3= tf.cast(matrix1, dtype=tf.int16)

# %%
matrix3
# Out:
# <tf.Tensor: shape=(2,), dtype=int16, numpy=array([1, 4], dtype=int16)>

# %%
matrix3= tf.cast(matrix1, dtype=tf.float16)
matrix3
# Out:
# <tf.Tensor: shape=(2,), dtype=float16, numpy=array([1., 4.], dtype=float16)>

# %%
matrix3= tf.cast(matrix1,dtype=tf.float32)
matrix3
# Out:
# <tf.Tensor: shape=(2,), dtype=float32, numpy=array([1., 4.], dtype=float32)>

# %%
matrix3
# Out:
# <tf.Tensor: shape=(2,), dtype=float32, numpy=array([1., 4.], dtype=float32)>

# %%
matrix3.dtype
# Out:
# tf.float32
